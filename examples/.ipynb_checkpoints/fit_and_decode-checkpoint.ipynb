# %%
import sys
sys.path.append("/home/diego/Dropbox/hold_noise/iclamp-glm/")
# import os
import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# import seaborn as sns

from icglm.glm_decoding import GLMDecoder
from icglm.glm_fitting import GLMFitter
from icglm.iclamp import IClamp
# from HoldNoise import HoldNoise
from icglm.kernels import KernelFun
# #from SpikeTrain import SpikeTrain

# #from fun_signals import get_arg

# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-aeeaafc9918c> in <module>
#       7 # import seaborn as sns
#       8
# ----> 9 from icglm.glm_decoding import GLMDecoder
#      10 from icglm.glm_fitting import GLMFitter
#      11 from icglm.iclamp import IClamp
#
# ~/Dropbox/hold_noise/iclamp-glm/icglm/glm_decoding.py in <module>
#       6
#       7 from .glm import GLM
# ----> 8 from .kernels import KernelVals
#       9
#      10 from fun_signals import get_dt, get_arg, diag_indices
#
# ImportError: cannot import name 'KernelVals'

# %%
ic = IClamp.load_from_abf(path='./18815080.abf')
ic = ic.subtract_Ih(th=1000.1).restrict(t0=1000.1, tf=11000.1)
ic.plot()
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f82c7309278>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f82c72d14e0>)

# %%
ic = IClamp.load_from_abf(path='./18815080.abf')
ic = ic.subtract_Ih(th=1000.1).restrict(t0=1000.1, tf=11000.1)

glm_fit = GLMFitter(ic).set_mask_spikes(thr=-13).subsample(10)

tbins_kappa = np.arange(0., 360, 5.)
tbins_eta = np.arange(0., 475., 25.)
newton_kwargs = {'max_iterations': 100, 'stop_cond': 5e-4, 'learning_rate': 1e-1}

glm_fit.fit(tbins_kappa=tbins_kappa, tbins_eta=tbins_eta, newton_kwargs=newton_kwargs)
glm_fit.plot_filters()

# %%
glm_fit.set_mask_spikes_model(trials=9)
glm_fit.psth(psth_kernel=KernelFun.gaussian_delta(delta=40))
glm_fit.plot_raster()

# %%
Imu, Istd = np.mean(glm_fit.ic.stim), np.mean(np.std(glm_fit.ic.stim, 0))

I0 = np.zeros(len(glm_fit.ic.t))
decoder = GLMDecoder(glm=[glm_fit.glm], t=glm_fit.ic.t, mask_spk=[glm_fit.mask_spikes], 
                     tau=3, Imu=[Imu], Istd=[Istd], I_true=(glm_fit.ic.stim - Imu) / Istd)

decoder.estimate_MAP_I(I0, optimization_kwargs=optimization_kwargs, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-984e9a45d383> in <module>
#       2
#       3 I0 = np.zeros(len(glm_fit.ic.t))
# ----> 4 decoder = GLMDecoder(glm=[glm_fit.glm], t=glm_fit.ic.t, mask_spk=[glm_fit.mask_spikes],
#       5                      tau=3, Imu=[Imu], Istd=[Istd], I_true=(glm_fit.ic.stim - Imu) / Istd)
#       6
#
# NameError: name 'GLMDecoder' is not defined
